# %% [markdown]
# # UPSIDE EDUCATION
#
# ### Table of Contents
# 1.[Question/Problem](#1.-Question/Problem)
#
# 2.[Introduction](#2.-Introduction)
#
# 3.[Survey](#3.-Survey)
#
# 4.[Analysis&Insights](#4.-Analysis&Insights)
#
# 5.[Proposed_Solution](#5.-Proposed_Solution)

# %% [markdown]
# ## 1.Question/Problem
# - How can we bridge the gap between the students and teachers?
# - Providing an excellent learning experience?
# - Ensuring full  coverage and proficiency in any of the subjects or field being learnt?

# %% [markdown]
# ## 2. Introduction

# %% [markdown]
# >> My main aim for this presentation is to breach the gap in the educational sector between the Students and the Teachers at the same time ensuring that every student gets a wonderful thorough learning experince and knowleged in whatever field or subject they choose to venture in .

# %% [markdown]
# > Imagine a class of 52 and a class of 200 being taught the same subject by one teacher , which of these classes will probably have a higher success rate in the subject being taught and which of these classes would have had a more closer supervision through out their period of learning ?
#
#
# >The class of 52 would come out true on both instances above.
# But what if that wasn't the case and both classes came out true in both cases ,tell me wouldn't that be great ? The fear a student has thinking he isn't going to enjoy the class due to the fact that they might be so many students in the class can now be a thing of the past .
#
#
# > Through **DATA SCIENCE** which helps in making the learner feel special in conjuction with an **ALLURING UI** which will help in captivating and motivating the learner. The above instance willbe a thing of the past .

# %% [markdown]
# ## 3. Survey

# %% [markdown]
# > A survey was taking using google forms to see what type of learning technique people prefer . I had a total of 33 responses from the survey and which I later analyzed for futher insights .
#
# >During my research on learning techniques , I came across a similar survey carried out to find out **what best strategies of teaching will be provided for better interaction and better learning process**.Similar to this survey I carried out this survey to find out  how to improve learning experience since everyone doesn't learn the same way

# %% [markdown]
# ### A display of the questions asked in the survey :
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# ![Capture2.PNG](attachment:Capture2.PNG)

# %% [markdown]
# ![Capture7.PNG](attachment:Capture7.PNG)

# %% [markdown]
# ### The gathered dataset:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
pd.set_option("display.max_rows", None, "display.max_columns", None)
df=pd.read_csv('Edu_data.csv')
df
# Out:
#            Name Education_LVL Learning_Practice   Pace_Learning  \
# 0        Gerald    University     Project-Based             Yes
# 1        Ugochi    University           Blended             Yes
# 2       Abraham   High_school           Blended             Yes
# 3          Ugbo    University            Online             Yes
# 4    Aderinsola    University           Blended             Yes
# 5        Akuoma    University     Project-Based  Doesn't_matter
# 6         Ebube   High_school          Physical             Yes
# 7   Janefrances    University           Blended             Yes
# 8     Gabriella   High_school     Project-Based  Doesn't_matter
# 9         Okoli    University           Blended             Yes
# 10        Kamso    University     Project-Based             Yes
# 11       Esther    University           Blended             Yes
# 12    Folorunso    University           Blended  Doesn't_matter
# 13     Chidinma    University          Physical             Yes
# ...

# %% [markdown]
# ##### Through this data you will notice that people prefer different ways of learning and opinions on the presence of a mentor/guide during the learning process.

# %% [markdown]
# ## 4. Analysis&Insights

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# ![download-2.png](attachment:download-2.png)

# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# > - This survey shows that most of the inputs  came from students in University level and the type of the learning technique preferred by most students is the **Blending** seconded by the **Project_Based** learning techniques.
# > - Most of the student prefer learning at their own **Pace** and regard the presence of a **Mentor/Teacher** to monitor their progress and give responsive feed backs to be highly important  and also find the presence of a 24/7 guide **PLeasant**.

# %% [markdown]
# ### Futher analysis

# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# > - Diving further into the dataset it's seen that **Blended_learning** is highly preferred by students in every educational level and **Pace learning** is appreciated by every student.
# > - The insights drawn from importance and availability of a mentor or guide is still very much **Pleasant** in every educational level.

# %% [markdown]
# ## 5. Proposed_Solution

# %% [markdown]
# ## Summary of the Platform
# I suggest building a software which will have an intregrated algorithm for the purpose of learning the users/learners skills and help improve the users knowledge and skills in the field the users chooses to learn or venture. The software will have to integrate a very attracting UI which will keep the user intrested and also help by increasing his time spent learnng .

# %% [markdown]
# ### Increasing  the time spent learning
# > **The main goal of this solution is to create a platform that is best set to each individual learning preference in hopes of giviving the best User experience and achieving ones goals.**

# %% [markdown]
# >I propose a platform which could help increase the learners devotion to learning by integrating a UI that can captivate the learners mind and also integrate a very interactive simulation just like a game but one in which the learner will not find learning tedious. Such integrations could be:

# %% [markdown]
# - ***Availaibility of different learning themes:***
#
# >>Learning in an enviroment that has maybe one of your favourite movies as the theme setting ,would be very intresting and make the learning process seem fun. For example , I love the movie Harry potter and there's a theme like that and I choose that as my new theme.Everytime I open the learning platform ,it displays something like this;

# %% [markdown]
# ![Instagram%20Post%201080x1080%20px.jpeg](attachment:Instagram%20Post%201080x1080%20px.jpeg)

# %% [markdown]
# ## ***Integrating  an algorithm that grows with the user/learner:***
# > Spotify is highly recommended and has been said to be the best music listening platform, this is because of the amazing algorithm integrated in the app which studies the type of music the user listens to and also recieves data on the type of sound and musicians the user enjoys listening to .

# %% [markdown]
# >>The more data we have about our user the more we can make the user feel comfortable and intrested while learning . Using data science to create an algorithm that will be trained to activate different teaching techiques based on the data the user feeds the data.

# %% [markdown]
# >Data will be gotten from the user by asking questions during the registration or the signing up stage such as :
# - Name ?
# - Age ?
# - Current Educational_level ?
# - Type of learning techniques preferred by you ?
# - Program to be studied ?
# - Why are you studying this program (Exam/Job/General knowledge)?
# - Future Occupation?
# >Through the continuous gathering of this data and proper monitoring of the learners pattern when learning , in the future the algorithm will be able to predict the  maximum amount of time needed to be put in to guarantee an excellent result in whatever field or skill being learnt .

# %% [markdown]
# ### Motivating the learners
# > The platform will have a system that helps motivate the learners by bringing up wonderful facts about their role models or from their respective intrested fields , for eample ;
# - **Lets help you be as succesful as Denzel Washighton**
#                        OR
# - **Through constant practicing and hardwork on balancing acoounting sheets you could be the head of an accounting team at a very young age in a multi international company** e.t.c .
# > By asking the user to write a list of his role models when signing up .
# - Role models?

# %% [markdown]
# ## The Perfect Teachers Assistant:
# > With the implementation of this algorithm , the workload on the the teacher is greatly reduced and the student have a 24/7 guide who sole priority isto ensure the progres of the student.

# %% [markdown]
# > By studying the progress of a student through their test scores in every checkpoint or each section of the subject or field being learnt , the platform will tell the student ,in what part he needs to revisit to attain mastery or in ensuring  a good grade .The platform will also help in referring extra  videos or writings in the that particular field.

# %% [markdown]
# > The platform will help in giving the teacher feed back on the time spent by the student each day and how many attempts the students had before answering a test question grading the student with each try but this inforation  is only visible to the teacher, to help the teacher know when a student is stuck on a certain task or isn't progressing .This will also help the teacher in having a very direct conversation with the student and hence build a relationship  between the teacher and student . A **Request Guide** option wil aslo be implented in order for the student to reach out for assistance immidiately and if the teacher is not answering the student could relay the question to the
